# %%
# importing Packages

from bs4 import BeautifulSoup
from selenium import webdriver
import time
import pandas as pd
import requests

# %% [markdown]
# Using Selenium and Beautiful Soup to extract various games links from the website

# %%
# Initialize WebDriver
driver = webdriver.Chrome()  # You should replace this with the appropriate web driver you're using (Chrome, Firefox, etc.)

# Open the URL of the webpage
url = "https://rawg.io/games"
driver.get(url)

# Automatically scroll the page
scroll_pause_time = 2  # Pause between each scroll
screen_height = driver.execute_script("return window.screen.height;")  # Browser window height

for i in range(350):
    # Scroll down
    driver.execute_script(f"window.scrollTo(0, {screen_height * i});")
    i += 1
    time.sleep(scroll_pause_time)

# Fetch the data using BeautifulSoup after all data is loaded
soup = BeautifulSoup(driver.page_source, "html.parser")
# Process and save the data as needed

# Close the WebDriver session
driver.quit()

# %%
# storing links to use
links = soup.find_all("a", attrs = {"class":"game-card-medium__info__name"})

# %%
links
# Out:
# [<a class="game-card-medium__info__name" href="/games/grand-theft-auto-v">Grand Theft Auto V<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/tomb-raider">Tomb Raider (2013)<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/bioshock-infinite">BioShock Infinite<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/half-life-2">Half-Life 2<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/god-of-war-2">God of War (2018)<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/team-fortress-2">Team Fortress 2<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/rocket-league">Rocket League<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/metro-2033">Metro 2033<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/the-witcher-2-assassins-of-kings-enhanced-edition">The Witcher 2: Assassins of Kings Enhanced Edition<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/shadow-of-mordor">Middle-earth: Shadow of Mordor<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/bioshock-2">BioShock 2<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/hitman">Hitman<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/outlast">Outlast<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/marvels-spider-man">Marvel's Spider-Man<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/half-life">Half-Life<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/path-of-exile">Path of Exile<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/playerunknowns-battlegrounds">PlayerUnknown’s Battlegrounds<div class="rating rating_emoji rating_meh game-card-medium__info__rating" role="button" tabindex="0" title="meh"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/fallout-new-vegas">Fallout: New Vegas<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/the-elder-scrolls-v-skyrim-special-edition">The Elder Scrolls V: Skyrim Special Edition<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/company-of-heroes-2">Company of Heroes 2<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/hellblade-senuas-sacrifice">Hellblade: Senua's Sacrifice<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/half-life-deathmatch-source">Half-Life Deathmatch: Source<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/dont-starve-together">Don't Starve Together<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/metal-gear-solid-v-ground-zeroes">Metal Gear Solid V: Ground Zeroes<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/metro-last-light-redux">Metro: Last Light Redux<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/bastion">Bastion<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/bioshock-2-remastered">BioShock 2 Remastered<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/monster-hunter-world-2">Monster Hunter: World<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/brutal-legend">Brutal Legend<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/paladins">Paladins<div class="rating rating_emoji rating_meh game-card-medium__info__rating" role="button" tabindex="0" title="meh"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/hades-2018">Hades<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/watch-dogs">Watch Dogs<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/max-payne-3">Max Payne 3<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/saints-row-iv">Saints Row IV<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/firewatch">Firewatch<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/warhammer-vermintide-2">Warhammer: Vermintide 2<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/transistor">Transistor<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/cuphead">Cuphead<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/no-mans-sky">No Man's Sky<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/the-wolf-among-us">The Wolf Among Us<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/the-stanley-parable">The Stanley Parable<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/doom-eternal">DOOM Eternal<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/trine-2-complete-story">Trine 2: Complete Story<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/viscera-cleanup-detail-shadow-warrior">Viscera Cleanup Detail: Shadow Warrior<div class="rating rating_emoji rating_meh game-card-medium__info__rating" role="button" tabindex="0" title="meh"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/soma">SOMA<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/watch_dogs-2">Watch Dogs 2<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/cod-black-ops-iii">Call of Duty: Black Ops III<div class="rating rating_emoji rating_meh game-card-medium__info__rating" role="button" tabindex="0" title="meh"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/dead-island">Dead Island<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/lara-croft-and-the-temple-of-osiris">Lara Croft and the Temple of Osiris<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games
div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/broken-age">Broken Age<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/assassins-creed-brotherhood-2">Assassin’s Creed Brotherhood<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/oxenfree">Oxenfree<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/monaco-whats-yours-is-mine">Monaco: What's Yours Is Mine<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/fear-3">F.E.A.R. 3<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/planetside-2">PlanetSide 2<div class="rating rating_emoji rating_meh game-card-medium__info__rating" role="button" tabindex="0" title="meh"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/killer-is-dead-nightmare-edition">Killer is Dead - Nightmare Edition<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/persona-5">Persona 5<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/stray-2">Stray<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/spelunky">Spelunky<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/the-talos-principle">The Talos Principle<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/divinity-original-sin">Divinity: Original Sin<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/the-swapper">The Swapper<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/binary-domain">Binary Domain<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/mass-effect-3">Mass Effect 3<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/deep-rock-galactic">Deep Rock Galactic<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/vrchat">VRChat<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/gears-5">Gears 5<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/call-of-duty-world-at-war">Call of Duty: World at War<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/it-takes-two-2">It Takes Two<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/the-elder-scrolls-iv-oblivion-game-of-the-year-edi">The Elder Scrolls IV: Oblivion Game of the Year Edition<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/stalker-call-of-pripyat">S.T.A.L.K.E.R.: Call of Pripyat<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/deponia-the-complete-journey">Deponia: The Complete Journey<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/sunset-overdrive">Sunset Overdrive<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/torchlight">Torchlight<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/day-of-defeat">Day of Defeat<div class="rating rating_emoji rating_meh game-card-medium__info__rating" role="button" tabindex="0" title="meh"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/system-shock-2">System Shock 2<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/awesomenauts">Awesomenauts<div class="rating rating_emoji rating_meh game-card-medium__info__rating" role="button" tabindex="0" title="meh"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/deadlight">Deadlight<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/outlast-2">Outlast 2<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/deathloop-2">Deathloop<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/outland">Outland<div class="rating rating_emoji rating_meh game-card-medium__info__rating" role="button" tabindex="0" title="meh"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/kholat">Kholat<div class="rating rating_emoji rating_meh game-card-medium__info__rating" role="button" tabindex="0" title="meh"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/spyro-reignited-trilogy">Spyro Reignited Trilogy<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/renegade-ops">Renegade Ops<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/clicker-heroes">Clicker Heroes<div class="rating rating_emoji rating_meh game-card-medium__info__rating" role="button" tabindex="0" title="meh"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/mortal-kombat-komplete-edition">Mortal Kombat Komplete Edition<div class="rating rating_emoji rating_recommended game-card-medium__info__rating" role="button" tabindex="0" title="recommended"></div></a>,
#  <a class="game-card-medium__info__name" href="/games/uncharted-2-among-thieves">Uncharted 2: Among Thieves<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>,
#  ...]

# %%
# Testing links list
links[0]
# Out:
# <a class="game-card-medium__info__name" href="/games/grand-theft-auto-v">Grand Theft Auto V<div class="rating rating_emoji rating_exceptional game-card-medium__info__rating" role="button" tabindex="0" title="exceptional"></div></a>

# %%
link_1 = links[0].get('href')

# %%
# Creating a test link to test out extraction methods before making a function for them
game_link = "https://rawg.io"+link_1

# %%
game_link
# Out:
# 'https://rawg.io/games/grand-theft-auto-v'

# %%
headers = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36', 'Accept-Language' : 'en-US, en;q=0.5'})

# %%
game_page = requests.get(game_link, headers = headers)

# %%
game_page
# Out:
# <Response [200]>

# %%
game_soup = BeautifulSoup(game_page.content, 'html.parser')

# %%
# Testing Getting Title
game_soup.find("h1", attrs = {'class': 'heading heading_1 game__title'}).text.strip()
# Out:
# 'Grand Theft Auto V'

# %%
# Funtion to return title

def get_title(soup):
    try:
        title = soup.find("h1", attrs = {'class': 'heading heading_1 game__title'}).text.strip()
    except AttributeError:
        title = ''
    return(title)

# %%
# Testing getting platforms
game_soup.find("div", attrs = {'class': 'game__meta-text'}).text.strip()
# Out:
# 'PlayStation 5, Xbox Series S/X, PC, PlayStation 4, PlayStation 3, Xbox 360, Xbox One'

# %%
# Function to get platforms

def get_platform(soup):
    try:
        platform = soup.find("div", attrs = {'class': 'game__meta-text'}).text.strip()
    except AttributeError:
        platform = ''
    return (platform)

# %%
# Testing getting release date
game_soup.find("div", attrs = {'class': 'game__meta-text', 'itemprop' : 'datePublished'}).text.strip()
# Out:
# 'Sep 17, 2013'

# %%
# Function to get release date

def get_release_date(soup):
    try:
        date = soup.find("div", attrs = {'class': 'game__meta-text', 'itemprop' : 'datePublished'}).text.strip()
    except AttributeError:
        date = ''
    return (date)

# %%
# Testing getting game genre
game_genre = game_soup.find_all("meta", attrs = {'itemprop' : 'genre'})

# %%
for i in game_genre:
    print(i.get('content'))
# Out:
# Action
# Adventure

# %%
# Function to get genres

def get_genres(soup):
    genres = []
    try:
        genres1 = soup.find_all("meta", attrs = {'itemprop' : 'genre'})
        for i in genres1:
            x = i.get('content')
            x = str(x)
            genres.append(x)
        
        return (genres)
    
    except AttributeError:
        pass
    return (genres)

# %%
# Testing getting publisher name
game_soup.find("meta", attrs = {'itemprop': 'publisher'}).get('content')
# Out:
# 'Rockstar Games'

# %%
# Function to get publisher name

def get_publisher(soup):
    try:
        publisher = soup.find("meta", attrs = {'itemprop': 'publisher'}).get('content')
    except AttributeError:
        publisher = ''
    return (publisher)

# %%
# Testing getting game description
game_soup.find_all("p")[1].text
# Out:
# 'Rockstar Games went bigger, since their previous installment of the series. You get the complicated and realistic world-building from Liberty City of GTA4 in the setting of lively and diverse Los Santos, from an old fan favorite GTA San Andreas. 561 different vehicles (including every transport you can operate) and the amount is rising with every update. \nSimultaneous storytelling from three unique perspectives: \nFollow Michael, ex-criminal living his life of leisure away from the past, Franklin, a kid that seeks the better future, and Trevor, the exact past Michael is trying to run away from. \nGTA Online will provide a lot of additional challenge even for the experienced players, coming fresh from the story mode. Now you will have other players around that can help you just as likely as ruin your mission. Every GTA mechanic up to date can be experienced by players through the unique customizable character, and community content paired with the leveling system tends to keep everyone busy and engaged.'

# %%
game_soup.find("div", attrs = {'itemprop': 'description'}).find("p").text
# Out:
# 'Rockstar Games went bigger, since their previous installment of the series. You get the complicated and realistic world-building from Liberty City of GTA4 in the setting of lively and diverse Los Santos, from an old fan favorite GTA San Andreas. 561 different vehicles (including every transport you can operate) and the amount is rising with every update. \nSimultaneous storytelling from three unique perspectives: \nFollow Michael, ex-criminal living his life of leisure away from the past, Franklin, a kid that seeks the better future, and Trevor, the exact past Michael is trying to run away from. \nGTA Online will provide a lot of additional challenge even for the experienced players, coming fresh from the story mode. Now you will have other players around that can help you just as likely as ruin your mission. Every GTA mechanic up to date can be experienced by players through the unique customizable character, and community content paired with the leveling system tends to keep everyone busy and engaged.'

# %%
# Function to get Description

def get_description(soup):
    try:
        description = soup.find("div", attrs = {'itemprop': 'description'}).find("p").text
    except AttributeError:
        description = ''
    return (description)

# %%
# Testing getting age rating
test_rating = game_soup.find_all("div", attrs = {'class': 'game__meta-text'})

# %%
test_rating[6]
# Out:
# <div class="game__meta-text">17+<!-- --> <!-- -->Mature</div>

# %%
# Function to get age rating

def get_age_rating(soup):
    try:
        age_rating_element = soup.find('div', {'class': 'game__meta-title'}, text='Age rating')
        age_rating = age_rating_element.find_next_sibling('div', {'class': 'game__meta-text'}).text
    except AttributeError:
        age_rating = ''
    return (age_rating)

# %%
# Testing getting metascore
game_soup.find("div", attrs = {'class': 'metascore-label metascore-label_green'}).text
# Out:
# '92'

# %%
# Function to get metascore

def get_metascore(soup):
    try:
        metascore = soup.find("div", attrs = {'class': 'metascore-label metascore-label_green'}).text
    except AttributeError:
        metascore = ''
    return (metascore)

# %%
# Creating a dictionary to convert to dataframe later
d = {'Title':[],'Platform':[],'Genres':[],'Release_date':[],'Publisher Name':[], 'Age Rating':[], 'Metascore':[], 'Description':[]}

# %%
# Getting the list of all links
links_list = []

for link in links:
    links_list.append(link.get('href'))

# %%
# Extraction of information from all links 

for link in links_list:
    webpage = requests.get("https://rawg.io"+link, headers = headers)
    new_soup = BeautifulSoup(webpage.content, "html.parser")
    
    # Applying functions to get values
    d['Title'].append(get_title(new_soup))
    d['Platform'].append(get_platform(new_soup))
    d['Genres'].append(get_genres(new_soup))
    d['Release_date'].append(get_release_date(new_soup))
    d['Publisher Name'].append(get_publisher(new_soup))
    d['Age Rating'].append(get_age_rating(new_soup))
    d['Metascore'].append(get_metascore(new_soup))
    d['Description'].append(get_description(new_soup))
    
    
    games_df = pd.DataFrame.from_dict(d)

# %%
games_df
# Out:
#                                   Title  \
# 0                    Grand Theft Auto V
# 1                    Tomb Raider (2013)
# 2                     BioShock Infinite
# 3                           Half-Life 2
# 4                     God of War (2018)
# ...                                 ...
# 3475                 Motorsport Manager
# 3476  Freedom Force vs. the Third Reich
# 3477          Army of Two: The 40th Day
# 3478           Kivi, Toilet and Shotgun
# 3479                       Sakura Beach
#
#                                                Platform  \
# 0     PlayStation 5, Xbox Series S/X, PC, PlayStatio...
# 1     PlayStation 4, macOS, PC, Xbox One, Xbox 360, ...
# 2     PlayStation 4, Xbox 360, Nintendo Switch, Linu...
# 3             PC, macOS, Xbox 360, Linux, Xbox, Android
# 4                                     PC, PlayStation 4
# ...                                                 ...
# 3475                                   iOS, PC, Android
# 3476                                                 PC
# 3477                            PlayStation 3, Xbox 360
# 3478                                                 PC
# 3479                                          Linux, PC
#
#                                       Genres  Release_date  \
# 0                        [Action, Adventure]  Sep 17, 2013
# 1                        [Action, Adventure]   Mar 5, 2013
# 2                          [Action, Shooter]  Mar 26, 2013
# 3                          [Action, Shooter]  Nov 16, 2004
# 4                   [Action, Adventure, RPG]  Apr 20, 2018
# ...                                      ...           ...
# 3475  [Strategy, Simulation, Sports, Racing]  Aug 21, 2014
# 3476                 [Action, RPG, Strategy]  May 29, 2005
# 3477            [Action, Shooter, Adventure]   Jan 8, 2010
# 3478      [Action, Adventure, Casual, Indie]  Jan 15, 2016
# 3479                     [Simulation, Indie]  Aug 14, 2015
#
#                       Publisher Name        Age Rating Metascore  \
# 0                     Rockstar Games        17+ Mature        92
# 1                        Square Enix        17+ Mature        86
# 2                           2K Games        17+ Mature        94
# 3                              Valve        17+ Mature        96
# 4     Sony Interactive Entertainment        17+ Mature        94
# ...                              ...               ...       ...
# 3475                            SEGA  10+ Everyone 10+        81
# 3476                        2K Games          13+ Teen        86
# 3477                 Electronic Arts        17+ Mature        84
# 3478           Back To Basics Gaming         Not rated        82
# 3479                    Winged Cloud         Not rated
#
#                                             Description
# 0     Rockstar Games went bigger, since their previo...
# 1     A cinematic revival of the series in its actio...
# 2     The third game in the series, Bioshock takes t...
# 3     Gordon Freeman became the most popular nameles...
# 4     It is a new beginning for Kratos. Living as a ...
# ...                                                 ...
# 3475
# 3476  Freedom is threatened yet again and only Minut...
# 3477  A carefully orchestrated series of mysterious ...
# 3478
# 3479
#
# [3480 rows x 8 columns]

# %%
# Droping null values
games_df = games_df.dropna(subset = ['Title'])

# %%
games_df
# Out:
#                                   Title  \
# 0                    Grand Theft Auto V
# 1                    Tomb Raider (2013)
# 2                     BioShock Infinite
# 3                           Half-Life 2
# 4                     God of War (2018)
# ...                                 ...
# 3475                 Motorsport Manager
# 3476  Freedom Force vs. the Third Reich
# 3477          Army of Two: The 40th Day
# 3478           Kivi, Toilet and Shotgun
# 3479                       Sakura Beach
#
#                                                Platform  \
# 0     PlayStation 5, Xbox Series S/X, PC, PlayStatio...
# 1     PlayStation 4, macOS, PC, Xbox One, Xbox 360, ...
# 2     PlayStation 4, Xbox 360, Nintendo Switch, Linu...
# 3             PC, macOS, Xbox 360, Linux, Xbox, Android
# 4                                     PC, PlayStation 4
# ...                                                 ...
# 3475                                   iOS, PC, Android
# 3476                                                 PC
# 3477                            PlayStation 3, Xbox 360
# 3478                                                 PC
# 3479                                          Linux, PC
#
#                                       Genres  Release_date  \
# 0                        [Action, Adventure]  Sep 17, 2013
# 1                        [Action, Adventure]   Mar 5, 2013
# 2                          [Action, Shooter]  Mar 26, 2013
# 3                          [Action, Shooter]  Nov 16, 2004
# 4                   [Action, Adventure, RPG]  Apr 20, 2018
# ...                                      ...           ...
# 3475  [Strategy, Simulation, Sports, Racing]  Aug 21, 2014
# 3476                 [Action, RPG, Strategy]  May 29, 2005
# 3477            [Action, Shooter, Adventure]   Jan 8, 2010
# 3478      [Action, Adventure, Casual, Indie]  Jan 15, 2016
# 3479                     [Simulation, Indie]  Aug 14, 2015
#
#                       Publisher Name        Age Rating Metascore  \
# 0                     Rockstar Games        17+ Mature        92
# 1                        Square Enix        17+ Mature        86
# 2                           2K Games        17+ Mature        94
# 3                              Valve        17+ Mature        96
# 4     Sony Interactive Entertainment        17+ Mature        94
# ...                              ...               ...       ...
# 3475                            SEGA  10+ Everyone 10+        81
# 3476                        2K Games          13+ Teen        86
# 3477                 Electronic Arts        17+ Mature        84
# 3478           Back To Basics Gaming         Not rated        82
# 3479                    Winged Cloud         Not rated
#
#                                             Description
# 0     Rockstar Games went bigger, since their previo...
# 1     A cinematic revival of the series in its actio...
# 2     The third game in the series, Bioshock takes t...
# 3     Gordon Freeman became the most popular nameles...
# 4     It is a new beginning for Kratos. Living as a ...
# ...                                                 ...
# 3475
# 3476  Freedom is threatened yet again and only Minut...
# 3477  A carefully orchestrated series of mysterious ...
# 3478
# 3479
#
# [3480 rows x 8 columns]

# %%
games_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3480 entries, 0 to 3479
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           3480 non-null   object
#  1   Platform        3480 non-null   object
#  2   Genres          3480 non-null   object
#  3   Release_date    3480 non-null   object
#  4   Publisher Name  3480 non-null   object
#  5   Age Rating      3480 non-null   object
#  6   Metascore       3480 non-null   object
#  7   Description     3480 non-null   object
# dtypes: object(8)
# memory usage: 217.6+ KB

# %%
# Converting Genres Coulmn to a column containg string values rather than lists

def joining_genres(lis):
    return (", ".join(lis))

# %%
games_df['Genres'] = games_df['Genres'].apply(joining_genres)

# %%
games_df
# Out:
#                                   Title  \
# 0                    Grand Theft Auto V
# 1                    Tomb Raider (2013)
# 2                     BioShock Infinite
# 3                           Half-Life 2
# 4                     God of War (2018)
# ...                                 ...
# 3475                 Motorsport Manager
# 3476  Freedom Force vs. the Third Reich
# 3477          Army of Two: The 40th Day
# 3478           Kivi, Toilet and Shotgun
# 3479                       Sakura Beach
#
#                                                Platform  \
# 0     PlayStation 5, Xbox Series S/X, PC, PlayStatio...
# 1     PlayStation 4, macOS, PC, Xbox One, Xbox 360, ...
# 2     PlayStation 4, Xbox 360, Nintendo Switch, Linu...
# 3             PC, macOS, Xbox 360, Linux, Xbox, Android
# 4                                     PC, PlayStation 4
# ...                                                 ...
# 3475                                   iOS, PC, Android
# 3476                                                 PC
# 3477                            PlayStation 3, Xbox 360
# 3478                                                 PC
# 3479                                          Linux, PC
#
#                                     Genres  Release_date  \
# 0                        Action, Adventure  Sep 17, 2013
# 1                        Action, Adventure   Mar 5, 2013
# 2                          Action, Shooter  Mar 26, 2013
# 3                          Action, Shooter  Nov 16, 2004
# 4                   Action, Adventure, RPG  Apr 20, 2018
# ...                                    ...           ...
# 3475  Strategy, Simulation, Sports, Racing  Aug 21, 2014
# 3476                 Action, RPG, Strategy  May 29, 2005
# 3477            Action, Shooter, Adventure   Jan 8, 2010
# 3478      Action, Adventure, Casual, Indie  Jan 15, 2016
# 3479                     Simulation, Indie  Aug 14, 2015
#
#                       Publisher Name        Age Rating Metascore  \
# 0                     Rockstar Games        17+ Mature        92
# 1                        Square Enix        17+ Mature        86
# 2                           2K Games        17+ Mature        94
# 3                              Valve        17+ Mature        96
# 4     Sony Interactive Entertainment        17+ Mature        94
# ...                              ...               ...       ...
# 3475                            SEGA  10+ Everyone 10+        81
# 3476                        2K Games          13+ Teen        86
# 3477                 Electronic Arts        17+ Mature        84
# 3478           Back To Basics Gaming         Not rated        82
# 3479                    Winged Cloud         Not rated
#
#                                             Description
# 0     Rockstar Games went bigger, since their previo...
# 1     A cinematic revival of the series in its actio...
# 2     The third game in the series, Bioshock takes t...
# 3     Gordon Freeman became the most popular nameles...
# 4     It is a new beginning for Kratos. Living as a ...
# ...                                                 ...
# 3475
# 3476  Freedom is threatened yet again and only Minut...
# 3477  A carefully orchestrated series of mysterious ...
# 3478
# 3479
#
# [3480 rows x 8 columns]

# %%
# Exporting games_df as a csv file for further use
games_df.to_csv("games_data.csv", header = True, index = False)
